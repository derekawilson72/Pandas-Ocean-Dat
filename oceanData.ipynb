# %% [markdown]
# # OceanData

# %% [markdown]
# import the module

# %%
import oceanData
# %matplotlib inline

# %% [markdown]
# Instantiate the Class

# %%
od1=oceanData.oceanDataPlot()

# %%
od1.WaveData.head()
# Out:
#                           Wvht  Wvdr
# date
# 2011-01-01 00:00:00   1.129027   333
# 2011-01-01 00:06:00  -3.360876    36
# 2011-01-01 00:12:00 -28.914305   305
# 2011-01-01 00:18:00  -3.277008   164
# 2011-01-01 00:24:00  20.538674     6

# %%
od1.WindData.head()
# Out:
#                          Wspd  Wndr
# date
# 2011-01-02 00:00:00  0.350247   224
# 2011-01-02 00:06:00  1.047135   246
# 2011-01-02 00:12:00  3.670854   178
# 2011-01-02 00:18:00  2.942719   333
# 2011-01-02 00:24:00  1.106067    96

# %% [markdown]
# Perform Analysis by determining the intersecting dates of wave and wind data.

# %%
od1.intersectDates()

# %% [markdown]
# ## Plot the results

# %%
od1.plotDates()##create timeline plot of wave and wind data
od1.fig.show()

# %% [markdown]
# Create a Wind Rose plot of the wind rose data.

# %%
od1.createWindRose() ## create roseplot of wind data

# %% [markdown]
# create a wave rose of the wave data

# %%
od1.createWaveRose() ##create rose plot of wave data
