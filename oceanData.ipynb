# %% [markdown]
# # OceanData

# %% [markdown]
# import the module

# %%
import oceanData
# %matplotlib inline

# %% [markdown]
# Instantiate the Class

# %%
od1=oceanData.oceanDataPlot()

# %% [markdown]
# Perform Analysis

# %%
od1.intersectDates()

# %% [markdown]
# Plot the results

# %%
od1.plotDates()
od1.fig.show()
